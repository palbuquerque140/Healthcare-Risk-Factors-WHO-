# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('../Data/train_preprocessed.csv')

# %%
df
# Out:
#             Age   Glucose  Blood Pressure       BMI  Oxygen Saturation  \
# 0      0.020409 -0.949270        0.921535  1.119114           0.532989
# 1      1.581744 -1.228016       -0.863656 -0.232136          -0.737363
# 2     -0.522665  0.207498       -1.158036  0.384132          -0.493990
# 3     -0.590549 -0.161827        1.246579 -0.246103           0.883338
# 4     -0.929970 -1.308992       -0.403687  0.860736          -0.777479
# ...         ...       ...             ...       ...                ...
# 20395 -0.481934 -0.480023       -0.275918  1.134826          -1.031550
# 20396  0.020409 -0.425519       -0.634693  0.144957          -0.400386
# 20397  0.088293  0.847782       -0.488525 -0.640654           0.423337
# 20398 -1.201507 -0.488328       -1.176435 -0.179762          -0.285385
# 20399 -1.201507 -0.750723       -2.336578 -0.940932           0.252174
#
#        Cholesterol  Triglycerides     HbA1c   Smoking   Alcohol  \
# 0        -0.087165      -0.409764 -1.131017  1.620501  1.779035
# 1         1.477347       1.618654  0.575192  1.620501  1.779035
# 2        -0.118711       0.129825  0.180868 -0.617093 -0.562103
# 3         2.321952      -0.315228 -0.312037 -0.617093  1.779035
# 4        -0.344891       0.725275 -0.494032  1.620501 -0.562103
# ...            ...            ...       ...       ...       ...
# 20395     0.824103       2.020123  0.014039 -0.617093 -0.562103
# 20396    -0.273764       1.665308  0.044371 -0.617093 -0.562103
# 20397     1.170218       0.794232 -0.190706  1.620501 -0.562103
# 20398     1.257714      -0.608247 -1.017270 -0.617093 -0.562103
# 20399    -1.021051      -0.119200 -0.365119 -0.617093 -0.562103
#
#        Physical Activity  Diet Score  Family History  Stress Level  \
# 0              -0.825064   -0.148625       -0.879636      0.375813
# 1              -0.521054   -0.027763        1.136834      1.151285
# 2              -0.750307   -0.472753       -0.879636     -0.291454
# 3              -0.356589   -0.203562        1.136834     -0.273420
# 4              -0.595810   -1.077061        1.136834     -1.801822
# ...                  ...         ...             ...           ...
# 20395          -1.153994   -0.274980       -0.879636     -0.075043
# 20396          -0.944675    0.840243       -0.879636      0.177436
# 20397          -0.635680    0.180998        1.136834     -2.667465
# 20398           0.326189   -0.159612       -0.879636      0.822160
# 20399           1.033886   -0.005788       -0.879636     -1.540325
#
#        Sleep Hours  target
# 0        -1.092823       6
# 1         0.917099       5
# 2         0.210683       6
# 3        -0.235032       5
# 4         0.429335       6
# ...            ...     ...
# 20395     0.168634       6
# 20396     0.605939       0
# 20397     0.370467       0
# 20398     0.538661       2
# 20399     0.269551       1
#
# [20400 rows x 16 columns]

# %%
X = df.drop(columns=['target'])
y = df['target']

# %%
y.value_counts()
# Out:
# target
# 5    5696
# 3    5133
# 6    3086
# 4    2431
# 1    1630
# 0    1437
# 2     987
# Name: count, dtype: int64

# %% [markdown]
# ### Perform Stratified K-Fold (Unbalanced Dataset) ####
# ---

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
models = {
    "LogisticRegression": LogisticRegression(max_iter=1000),
    "DecisionTree": DecisionTreeClassifier(),
    "RandomForest": RandomForestClassifier(),
    "GradientBoosting": GradientBoostingClassifier(),
    "SVM": SVC(),
}

# %%
scoring = {
    'accuracy': 'accuracy',
    'precision_macro': make_scorer(precision_score, average='macro'),
    'recall_macro': make_scorer(recall_score, average='macro'),
    'f1_macro': make_scorer(f1_score, average='macro')
}

# %%
results = {}
for name, model in models.items():
    cv_results = cross_validate(model, X, y, cv=skf, scoring=scoring, return_train_score=True)

    results[name] = {}

    for metric in scoring.keys():
        train_scores = cv_results['train_'+metric]            
        train_mean_score = train_scores.mean() 
        results[name]['train_'+metric] = train_mean_score
        val_scores = cv_results['test_'+metric]
        val_mean_score = val_scores.mean()            
        results[name]['val_'+metric] = val_mean_score

# %%
results_df = pd.DataFrame (results)

# %%
results_df
# Out:
#                        LogisticRegression  DecisionTree  RandomForest  \
# train_accuracy                   0.855282      1.000000      1.000000
# val_accuracy                     0.853382      0.761471      0.860441
# train_precision_macro            0.810809      1.000000      1.000000
# val_precision_macro              0.808086      0.682552      0.838049
# train_recall_macro               0.782120      1.000000      1.000000
# val_recall_macro                 0.779591      0.683967      0.771138
# train_f1_macro                   0.792965      1.000000      1.000000
# val_f1_macro                     0.790243      0.682992      0.788647
#
#                        GradientBoosting       SVM
# train_accuracy                 0.905172  0.890417
# val_accuracy                   0.866765  0.865637
# train_precision_macro          0.890149  0.867172
# val_precision_macro            0.828674  0.827712
# train_recall_macro             0.851406  0.827886
# val_recall_macro               0.795948  0.793537
# train_f1_macro                 0.866960  0.842605
# val_f1_macro                   0.808627  0.806156

# %%
results_df.T
# Out:
#                     train_accuracy  val_accuracy  train_precision_macro  \
# LogisticRegression        0.855282      0.853382               0.810809
# DecisionTree              1.000000      0.761471               1.000000
# RandomForest              1.000000      0.860441               1.000000
# GradientBoosting          0.905172      0.866765               0.890149
# SVM                       0.890417      0.865637               0.867172
#
#                     val_precision_macro  train_recall_macro  val_recall_macro  \
# LogisticRegression             0.808086            0.782120          0.779591
# DecisionTree                   0.682552            1.000000          0.683967
# RandomForest                   0.838049            1.000000          0.771138
# GradientBoosting               0.828674            0.851406          0.795948
# SVM                            0.827712            0.827886          0.793537
#
#                     train_f1_macro  val_f1_macro
# LogisticRegression        0.792965      0.790243
# DecisionTree              1.000000      0.682992
# RandomForest              1.000000      0.788647
# GradientBoosting          0.866960      0.808627
# SVM                       0.842605      0.806156

# %% [markdown]
# DecisionTree and RandomForest show clear signs of overfitting. Val_scores and considerably lower than Train_scores.
# LR, GB, SVM all generalize quite well. LR is a good baseline model but GB and SVM have the best balance of performance + generalization.
# These 2 will be fine_tuned.

# %% [markdown]
# ### Fine Tuning ###
# ---

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
skf = StratifiedKFold (n_splits = 3, shuffle=True, random_state = 42)

# %%
svm = SVC()
gb = GradientBoostingClassifier()

# %%
param_svm = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto']
}

param_gb = {
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7]
}

# %%
search_svm = RandomizedSearchCV (svm, param_svm , cv=skf, n_iter=15, scoring = 'recall_macro', n_jobs=-1)

# %%
search_svm.fit(X,y)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#                    estimator=SVC(), n_iter=15, n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10],
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['linear', 'rbf', 'poly']},
#                    scoring='recall_macro')

# %%
print(" SVM Best params:", search_svm.best_params_)
print(" SVM Best recall_macro", search_svm.best_score_)
# Out:
#  SVM Best params: {'kernel': 'rbf', 'gamma': 'auto', 'C': 1}
#  SVM Best recall_macro 0.7934512926833838

# %%
search_gb = RandomizedSearchCV (gb, param_gb , cv=skf, n_iter=15, scoring = 'recall_macro', n_jobs=-1)

# %%
search_gb.fit(X,y)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#                    estimator=GradientBoostingClassifier(), n_iter=15, n_jobs=-1,
#                    param_distributions={'learning_rate': [0.01, 0.05, 0.1],
#                                         'max_depth': [3, 5, 7],
#                                         'n_estimators': [100, 200, 300]},
#                    scoring='recall_macro')

# %%
print(" GB Best params:", search_gb.best_params_)
print(" GB Best recall_macro:", search_gb.best_score_)
# Out:
#  GB Best params: {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.05}
#  GB Best recall_macro: 0.8004874934438119

# %%
final_model_gb = GradientBoostingClassifier (**search_gb.best_params_)
final_model_svm = SVC (**search_svm.best_params_)

# %%
final_model_svm.fit(X,y)
# Out:
# SVC(C=1, gamma='auto')

# %%
final_model_gb.fit(X,y)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, n_estimators=300)

# %%
import joblib

# %%
joblib.dump(final_model_svm, '../Models/fina_model_svm.pkl')
# Out:
# ['../Models/fina_model_svm.pkl']

# %%
joblib.dump(final_model_gb, '../Models/fina_model_gb.pkl')
# Out:
# ['../Models/fina_model_gb.pkl']
